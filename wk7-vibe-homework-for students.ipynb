# %% [markdown]
# # Let's prep our data

# %% [markdown]
# ### Get the data
#
# - Download to your computer <a href="https://drive.google.com/file/d/1-798fq909hN3x3UxBYUDZrkEaPTliyvJ/view?usp=sharing"> this 256MB file</a> that contains NYPD summons data from 2015-2025s.

# %%
## import libraries
import pandas as pd

# %%
# import data
nypd_summons = pd.read_csv("summons-15-25.csv")
nypd_summons.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1384334 entries, 0 to 1384333
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   SUMMONS_KEY            1384334 non-null  int64
#  1   SUMMONS_DATE           1384334 non-null  str
#  2   OFFENSE_DESCRIPTION    1384316 non-null  str
#  3   LAW_SECTION_NUMBER     1348831 non-null  str
#  4   LAW_DESCRIPTION        1309406 non-null  str
#  5   SUMMONS_CATEGORY_TYPE  1309321 non-null  str
#  6   AGE_GROUP              1354372 non-null  str
#  7   SEX                    1284382 non-null  str
#  8   RACE                   964769 non-null   str
#  9   JURISDICTION_CODE      1384334 non-null  int64
#  10  BORO                   1372084 non-null  str
#  11  PRECINCT_OF_OCCUR      1384334 non-null  int64
#  12  X_COORDINATE_CD        1383871 non-null  float64
#  13  Y_COORDINATE_CD        1383871 non-null  float64
#  14  Latitude               1383870 non-null  float64
#  15  Longitude              1383870 non-null  float64
#  16  Lon_Lat                1383870 non-null  str
#  17  YEAR                   1384334 non-null  int64
# dtypes: float64(4), int64(4), str(10)
# memory usage: 190.1 MB

# %% [markdown]
# ## Doesn't AI make learning coding obsolete?

# %% [markdown]
# Yes, it's excellent at data analysis and coding.
#
# But here are a few problems you might run into:
#
# - How will you investigate AI-related topics?
# - Hitting Limits – even with paid accounts.
# - Protecting sources.
# - Not infallibable.
#
# At Bloomberg, the rule is **you are responsible** for every number, analysis and finding you put into your pieces.
#
# So be prepared to understand and explain each of your decisions, including AI's guidance.

# %% [markdown]
# ## Traditonal coding v. Vibe Coding

# %% [markdown]
# **Traditional coding**
# - structured approach to learning syntax and rules first.
#
# **Vibe coding**
# - learning by experimenting, observing results, analyzing and iterating – with AI's assistance – rather than memorizing syntax.
#
# - still need to learn coding because you must understand what the code is doing, recognizing mistakes and incorrect interpretations of your prompts.
#
# So you need to retain control of your editorial decisions and process. AI can help write code, but understanding coding helps you trust — or question — the answers.

# %% [markdown]
# What are some things - terms, processes etc – that we learned so far?
# - Python is good at math
# - variables are characters in your data.
# - PEMDAS
# - f-strings
# - built in functions
#     - like what? len, type, print, abs, round
# - importing and reading data
# - understanding dataframes v. series
# - getting an overview of your data

# %% [markdown]
# # Interviewing Data

# %% [markdown]
# If AI can write the code, what questions might you ask based on your domain/beat knowledge?
#
# Let's step back to see how we <a href="https://docs.google.com/presentation/d/1oA50DVvcPT2IWDAHTXogD5lWsWk1TVq_sp5iIS1qQv8/edit?usp=sharing">"interview"</a> data.

# %% [markdown]
# ## Interviewing Data with AI

# %%
## Get a sample. 
nypd_summons.sample(10)
# Out:
#          SUMMONS_KEY SUMMONS_DATE            OFFENSE_DESCRIPTION  \
# 1012399    152389917   2016-04-20                      LITTERING
# 371291     204463936   2019-11-04  FEDERAL MOTOR VEH. SAFETY REG
# 1057585    150495010   2016-02-17         CONSUMPTION OF ALCOHOL
# 855911     157861476   2016-10-23               OTHER ADMIN CODE
# 356021     208545556   2020-01-26              OTHER TRANSIT REG
# 1209434    145007541   2015-08-01               OTHER ADMIN CODE
# 768651     165271297   2017-03-27    FAILURE TO COMPLY WITH SIGN
# 1153735    146412219   2015-09-23         CONSUMPTION OF ALCOHOL
# 221664     250570038   2022-09-03    FAILURE TO COMPLY WITH SIGN
# 800695     161760332   2017-02-02         CONSUMPTION OF ALCOHOL
#
#         LAW_SECTION_NUMBER      LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE  \
# 1012399             153.01          Health Code              LITTERNG
# 371291              CFR 49   NYS Transportation             NYS TRANS
# 1057585             10-125  Administrative Code               ALCOHOL
# 855911                9999  Administrative Code      OTHER ADMIN CODE
# 356021                9999                  ABC             OTHER ABC
# 1209434               9999  Administrative Code      OTHER ADMIN CODE
# 768651               3-Jan            Park Regs             PARK REGS
# 1153735             10-125  Administrative Code               ALCOHOL
# 221664               3-Jan            Park Regs             PARK REGS
# 800695              10-125  Administrative Code               ALCOHOL
#
#         AGE_GROUP  SEX            RACE  JURISDICTION_CODE       BORO  \
# 1012399       <18    M         UNKNOWN                  2   BROOKLYN
# 371291    UNKNOWN  NaN             NaN                  0      BRONX
# 1057585     18-24    M             NaN                  0   BROOKLYN
# 855911        65+    M             NaN                  0   BROOKLYN
# 356021      45-64    M  WHITE HISPANIC                  1  MANHATTAN
# 1209434     18-24    M             NaN                  0  MANHATTAN
# 768651      18-24    M             NaN                  0     QUEENS
# 1153735     45-64    M             NaN                  0      BRONX
# 221664      18-24    M           BLACK                  0   BROOKLYN
# 800695      45-64    M           BLACK                  2        NaN
#
#          PRECINCT_OF_OCCUR  X_COORDINATE_CD  Y_COORDINATE_CD   Latitude  \
# 1012399                 69        1016452.0         170415.0  40.634376
# 371291                  47        1018222.0         265545.0  40.895476
# 1057585                 83        1005726.0         197251.0  40.708067
# 855911                  83        1007756.0         194984.0  40.701840
# 356021                  34        1006041.0         255411.0  40.867700
# 1209434                 14         988546.0         214963.0  40.756707
# 768651                 110        1024814.0         211642.0  40.747500
# 1153735                 48        1013103.0         250303.0  40.853660
# 221664                  73        1010484.0         178488.0  40.656546
# 800695                  23         998730.0         226827.0  40.789260
#
#          Longitude                                        Lon_Lat  YEAR
# 1012399 -73.883981   POINT (-73.88398062199997 40.63437605200004)  2016
# 371291  -73.877123   POINT (-73.87712270799994 40.89547629000003)  2019
# 1057585 -73.922540   POINT (-73.92253988399995 40.70806734200004)  2016
# 855911  -73.915226   POINT (-73.91522581599996 40.70183980300004)  2016
# 356021  -73.921215               POINT (-73.92121505 40.86770011)  2020
# 1209434 -73.984495   POINT (-73.98449493899994 40.75670745900004)  2015
# 768651  -73.853605  POINT (-73.85360492599993 40.747500165000076)  2017
# 1153735 -73.895704   POINT (-73.89570405599994 40.85365993800008)  2015
# 221664  -73.905450               POINT (-73.90544994 40.65654612)  2022
# 800695  -73.947710   POINT (-73.94771000099996 40.78926022400003)  2017

# %% [markdown]
# ### What are some questions you could ask this data?

# %% [markdown]
# 1. Which borough had the most summons?
# 2. How many times did the top 10 most common offenses occur?
# 3. What are the total number of summons broken down by year?
# 4. What were some of the most unusual summons? (how do you define most unusual)
# 5. What is the count of summons by gender?
# 6. How many summons were issued by race?
# 7. Which borough had the fewest offenses per 100K people?

# %% [markdown]
# ### Upload data to AI - ask it questions.

# %% [markdown]
# #### What happened?

# %% [markdown]
# What do we do on deadline when the dataset is too big?
#
# Even if AI ingests a large dataset, it responds by analyzing a fraction of the data.
#
# The importance of <a href="https://docs.google.com/presentation/d/1BKn8iUq9wy3KgrcfbfpJN6i3cnB8dNlnbAQlrbUSGJ0/edit?usp=sharing">Reproducible Data Journalism</a>

# %% [markdown]
# ## And now let's interview data using Pandas

# %% [markdown]
# We are soon going to blend using AI and coding, but first it's important to understand some Pandas fundamentals.

# %% [markdown]
# #### Finally **Vibe Coding**!

# %% [markdown]
# ##### Template for Vibe Coding

# %% [markdown]
# 1. Give AI a sample of your data (like a 100 rows)
# 2. Ask it for the Pandas code to answer a question, **but always tell it to comment the code**!
# 3. Leave a comment in Markdown with your prompt
# 4. Test it out in a code cell.
# 5. If the code throws an error, copy the entire code and give it AI.
# 6. Remember to add this updated prompt to your markdown.
# 7. Test out the the updated code in same cell.
# 8. Create a markdown cell in which you use f-strings to leave your finding

# %% [markdown]
# #### 1. Give AI a sample of your data (like a 100 rows)

# %%
## see sample data
summons_sample = nypd_summons.sample(100)
summons_sample
# Out:
#          SUMMONS_KEY SUMMONS_DATE                        OFFENSE_DESCRIPTION  \
# 1175465    145937525   2015-09-01                     CONSUMPTION OF ALCOHOL
# 234974     246962982   2022-06-21  OBSTRUCTS VEHICULAR OR PEDESTRIAN TRAFFIC
# 1147220    146717860   2015-10-02                 OTHER GENERAL BUSINESS LAW
# 727178     165141587   2017-05-23              FEDERAL MOTOR VEH. SAFETY REG
# 723937     165270923   2017-05-28                UNLICENSED VEHICLE FOR HIRE
# ...              ...          ...                                        ...
# 1032832    151491503   2016-03-22                     CONSUMPTION OF ALCOHOL
# 470394     187199097   2018-09-04              FEDERAL MOTOR VEH. SAFETY REG
# 357554     208916363   2020-01-16              FEDERAL MOTOR VEH. SAFETY REG
# 826904     159353451   2016-12-13                   MARIJUANA, POSSESSION OF
# 810305     160446996   2017-01-17                  NO PREGNANCY WARNING SIGN
#
#         LAW_SECTION_NUMBER       LAW_DESCRIPTION       SUMMONS_CATEGORY_TYPE  \
# 1175465             10-125   Administrative Code                     ALCOHOL
# 234974           240.20(5)                (null)                      (null)
# 1147220               9999  General Business Law  OTHER GENERAL BUSINESS LAW
# 727178              CFR 49    NYS Transportation                   NYS TRANS
# 723937              19-506   Administrative Code                         TLC
# ...                    ...                   ...                         ...
# 1032832             10-125   Administrative Code                     ALCOHOL
# 470394              CFR 49    NYS Transportation                   NYS TRANS
# 357554                 NaN    NYS Transportation                   NYS TRANS
# 826904              221.05             Penal Law                   MARIJUANA
# 810305               105-B                   ABC                         ABC
#
#         AGE_GROUP  SEX            RACE  JURISDICTION_CODE       BORO  \
# 1175465     45-64    M             NaN                  2   BROOKLYN
# 234974      25-44    M  WHITE HISPANIC                  2      BRONX
# 1147220     25-44    F             NaN                  0  MANHATTAN
# 727178      25-44    M             NaN                  0      BRONX
# 723937      25-44    M           BLACK                  0   BROOKLYN
# ...           ...  ...             ...                ...        ...
# 1032832     25-44    M         UNKNOWN                  0   BROOKLYN
# 470394    UNKNOWN  NaN             NaN                  0      BRONX
# 357554    UNKNOWN  NaN             NaN                  0   BROOKLYN
# 826904      18-24    M           WHITE                  0     QUEENS
# 810305      25-44    M           WHITE                  0   BROOKLYN
#
#          PRECINCT_OF_OCCUR  X_COORDINATE_CD  Y_COORDINATE_CD   Latitude  \
# 1175465                 76         982705.0         185232.0  40.675104
# 234974                  40        1007021.0         236272.0  40.815158
# 1147220                 14         987587.0         212403.0  40.749681
# 727178                  40        1008496.0         232463.0  40.804708
# 723937                  78         991818.0         186117.0  40.677530
# ...                    ...              ...              ...        ...
# 1032832                 70         996652.0         170849.0  40.635617
# 470394                  45        1032091.0         241976.0  40.830722
# 357554                  78         990712.0         188399.0  40.683794
# 826904                 107        1032400.0         202285.0  40.721779
# 810305                  77         993466.0         185151.0  40.674877
#
#          Longitude                                        Lon_Lat  YEAR
# 1175465 -74.005571  POINT (-74.00557133299998 40.675103880000044)  2015
# 234974  -73.917735                POINT (-73.91773536 40.8151584)  2022
# 1147220 -73.987958  POINT (-73.98795774099993 40.749681321000025)  2015
# 727178  -73.912422   POINT (-73.91242183099996 40.80470811200007)  2017
# 723937  -73.972717   POINT (-73.97271700599998 40.67752990600008)  2017
# ...            ...                                            ...   ...
# 1032832 -73.955317   POINT (-73.95531736499998 40.63561713900003)  2016
# 470394  -73.827126               POINT (-73.82712606 40.83072233)  2018
# 357554  -73.976702               POINT (-73.97670221 40.68379436)  2020
# 826904  -73.826294  POINT (-73.82629388599996 40.721779500000025)  2016
# 810305  -73.966777   POINT (-73.96677689599994 40.67487689300003)  2017
#
# [100 rows x 18 columns]

# %%
# Summon the Head 
nypd_summons.head()
# Out:
#    SUMMONS_KEY SUMMONS_DATE               OFFENSE_DESCRIPTION  \
# 0    298767983   2024-12-31                DISORDERLY CONDUCT
# 1    298704187   2024-12-31                   IMPROPER PLATES
# 2    298787872   2024-12-31                          TRESPASS
# 3    298724988   2024-12-31     FEDERAL MOTOR VEH. SAFETY REG
# 4    298704460   2024-12-31  POSSESSION OF ALCOHOL BY A MINOR
#
#   LAW_SECTION_NUMBER     LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE AGE_GROUP  \
# 0              240.2           Penal Law    DISORDERLY CONDUCT     45-64
# 1                402                 VTL                   VTL     18-24
# 2             140.05           Penal Law              TRESPASS     25-44
# 3             CFR 49  NYS Transportation             NYS TRANS   UNKNOWN
# 4               65-C              (null)                (null)     18-24
#
#       SEX                      RACE  JURISDICTION_CODE       BORO  \
# 0       M            WHITE HISPANIC                  0  MANHATTAN
# 1       M  ASIAN / PACIFIC ISLANDER                  0      BRONX
# 2       F            BLACK HISPANIC                  2  MANHATTAN
# 3  (null)                    (null)                  0   BROOKLYN
# 4       M                     WHITE                  0  MANHATTAN
#
#    PRECINCT_OF_OCCUR  X_COORDINATE_CD  Y_COORDINATE_CD   Latitude  Longitude  \
# 0                 14         985927.0         213077.0  40.751523 -73.993947
# 1                 49        1020823.0         249562.0  40.851589 -73.867801
# 2                 32         998922.0         235604.0  40.813352 -73.946996
# 3                 94        1001547.0         203048.0  40.723980 -73.937597
# 4                  6         984439.0         204595.0  40.728254 -73.999318
#
#                                         Lon_Lat  YEAR
# 0  POINT (-73.99394730218468 40.75152348693427)  2024
# 1  POINT (-73.86780058180116 40.85158922344624)  2024
# 2                  POINT (-73.946996 40.813352)  2024
# 3  POINT (-73.93759674847603 40.72397961334044)  2024
# 4                  POINT (-73.999318 40.728254)  2024

# %%
## export
summons_sample.to_csv("sample_summons_100.csv", index = False, encoding = "UTF8")

# %% [markdown]
# ### Explanation of the export code
#
# `summons_sample` is the dataframe we want to export
#
# `.to_csv()` saves our dataframe to a .csv file. You are baseically exporting your python data out into a format that Excel, Google Sheets can read.
#
# `index=False`
# By default, on export pandas includes the DataFrame's index – the row numbers (0, 1, 2, 3...). We NEVER
# need it 99.99 percent of the time. `index=False` simply tells pandas to leave that column out on export.
#
# `encoding="utf-8"`
# Tells Python which character encoding to use when writing the file. `UTF-8` is the most universal standard — it handles English plus accented characters, symbols, non-Latin scripts, etc. without garbling them. If your data has names like "García" or "Müller" and you skip this, you might get weird characters or errors depending on your system.

# %% [markdown]
# Recall some questions we want to ask:
#
# 1. Which borough had the most summons?
# 2. How many times did the top 10 most common offenses occur?
# 3. What are the total number of summons broken down by year?
# 4. What were some of the most unusual summons? (how do you define most unusual)
# 5. What is the count of summons by gender?
# 6. How many summons were issued by race?
# 7. Which borough had the fewest offenses per 100K people?

# %% [markdown]
# ## Who wants to share their answers?

# %% [markdown]
# # Prompt for all questions #
# For all the following questions, use Pandas 2.5 or newer.
# Always provide comments for each line of code.

# %% [markdown]
# ### Prompt:
#
# Provide the pandas code to calculate which boroughs had the most summons (in descending order).

# %%
# 1. Which borough had the most summons? 

# Replace string '(null)' placeholders with real NaN so they're excluded cleanly
nypd_summons['BORO'] = nypd_summons['BORO'].replace('(null)', pd.NA)

# Count summons per borough, sort descending, and drop any missing borough values
borough_counts = (
    nypd_summons['BORO']
    .value_counts()              # Count occurrences of each borough; sorts descending by default
    .reset_index()               # Convert the Series into a two-column DataFrame
    .rename(columns={            # Rename columns from pandas defaults to readable names
        'BORO': 'borough',
        'count': 'summons_count'
    })
)

borough_counts
# Out:
#          borough  summons_count
# 0       BROOKLYN         427679
# 1          BRONX         312327
# 2      MANHATTAN         275884
# 3         QUEENS         246314
# 4       NEW YORK          63056
# 5  STATEN ISLAND          46824

# %%
# 2. What were the top 10 most common offenses?
nypd_summons.sample(10)
# Out:
#          SUMMONS_KEY SUMMONS_DATE            OFFENSE_DESCRIPTION  \
# 575016     306941748   2025-05-23                 ONE WAY STREET
# 1082185    149235948   2016-01-08  FEDERAL MOTOR VEH. SAFETY REG
# 1042865    151107957   2016-03-09         CONSUMPTION OF ALCOHOL
# 707126     166581597   2017-06-28                     BOX CUTTER
# 250570     242563941   2022-03-22                       TRESPASS
# 1063998    150174180   2016-02-06           NOISE (UNREASONABLE)
# 384510     202107914   2019-09-05    UNLICENSED VEHICLE FOR HIRE
# 893174     156432650   2016-09-03                 POSS. OF KNIFE
# 491852     183692843   2018-06-11       MAKES UNREASONABLE NOISE
# 1324930    141964915   2015-04-03               DISCON: FIGHTING
#
#         LAW_SECTION_NUMBER      LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE  \
# 575016                1127                  VTL                   VTL
# 1082185             CFR 49   NYS Transportation             NYS TRANS
# 1042865             10-125  Administrative Code               ALCOHOL
# 707126              10-134  Administrative Code                 KNIFE
# 250570              140.05            Penal Law              TRESPASS
# 1063998             24-218  Administrative Code                 NOISE
# 384510              19-506  Administrative Code                   TLC
# 893174              10-133  Administrative Code                 KNIFE
# 491852           240.20(2)                  NaN                   NaN
# 1324930           240.20-1            Penal Law    DISORDERLY CONDUCT
#
#         AGE_GROUP     SEX            RACE  JURISDICTION_CODE       BORO  \
# 575016     (null)  (null)  WHITE HISPANIC                  0     QUEENS
# 1082185       NaN       D             NaN                  0      BRONX
# 1042865     45-64       M         UNKNOWN                  2  MANHATTAN
# 707126      18-24       M           BLACK                  2      BRONX
# 250570      45-64       M           BLACK                  2      BRONX
# 1063998     25-44       M             NaN                  0     QUEENS
# 384510      45-64       M           BLACK                  0     QUEENS
# 893174      18-24       M         UNKNOWN                  1  MANHATTAN
# 491852      18-24       M           BLACK                  0      BRONX
# 1324930     25-44       M         UNKNOWN                  0     QUEENS
#
#          PRECINCT_OF_OCCUR  X_COORDINATE_CD  Y_COORDINATE_CD   Latitude  \
# 575016                 115        1022233.0         212649.0  40.750278
# 1082185                 40        1006459.0         232058.0  40.803602
# 1042865                 23        1001028.0         229572.0  40.796790
# 707126                  42        1012201.0         240878.0  40.827794
# 250570                  40        1006064.0         235307.0  40.812515
# 1063998                102        1034605.0         192486.0  40.694871
# 384510                 113        1052693.0         187158.0  40.680126
# 893174                  14         987866.0         214721.0  40.756044
# 491852                  44        1008704.0         243454.0  40.834875
# 1324930                108         998448.0         208963.0  40.740229
#
#          Longitude                                        Lon_Lat  YEAR
# 575016  -73.862913                   POINT (-73.862913 40.750278)  2025
# 1082185 -73.919781   POINT (-73.91978106899995 40.80360185200004)  2016
# 1042865 -73.939404   POINT (-73.93940440599994 40.79679044300008)  2016
# 707126  -73.899004   POINT (-73.89900386999993 40.82779397400003)  2017
# 250570  -73.921193                   POINT (-73.921193 40.812515)  2022
# 1063998 -73.818412        POINT (-73.818412358 40.69487134000008)  2016
# 384510  -73.753238  POINT (-73.75323823699995 40.680125856000075)  2019
# 893174  -73.986950   POINT (-73.98694954399997 40.75604353500006)  2016
# 491852  -73.911630               POINT (-73.91163046 40.83487473)  2018
# 1324930 -73.948766  POINT (-73.94876611299998 40.740228615000035)  2015

# %%
# 3. What are the total number of summons broken down by year?
nypd_summons['SUMMONS_DATE'] = nypd_summons['SUMMONS_DATE'].value_counts().sort_values(ascending=False)

print(nypd_summons)
# Out:
#          SUMMONS_KEY  SUMMONS_DATE               OFFENSE_DESCRIPTION  \
# 0          298767983           NaN                DISORDERLY CONDUCT
# 1          298704187           NaN                   IMPROPER PLATES
# 2          298787872           NaN                          TRESPASS
# 3          298724988           NaN     FEDERAL MOTOR VEH. SAFETY REG
# 4          298704460           NaN  POSSESSION OF ALCOHOL BY A MINOR
# ...              ...           ...                               ...
# 1384329    140411914           NaN                         LITTERING
# 1384330    140463604           NaN          MARIJUANA, POSSESSION OF
# 1384331    140424873           NaN                  OTHER ADMIN CODE
# 1384332    140418300           NaN           AFTER HOURS CONSUMPTION
# 1384333    140418234           NaN       DISCON: REFUSE LAWFUL ORDER
#
#         LAW_SECTION_NUMBER      LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE  \
# 0                    240.2            Penal Law    DISORDERLY CONDUCT
# 1                      402                  VTL                   VTL
# 2                   140.05            Penal Law              TRESPASS
# 3                   CFR 49   NYS Transportation             NYS TRANS
# 4                     65-C               (null)                (null)
# ...                    ...                  ...                   ...
# 1384329             16-118  Administrative Code             LITTERING
# 1384330             221.05            Penal Law             MARIJUANA
# 1384331               9999  Administrative Code      OTHER ADMIN CODE
# 1384332              106-5                  ABC                   ABC
# 1384333           240.20-6            Penal Law    DISORDERLY CONDUCT
#
#         AGE_GROUP     SEX                      RACE  JURISDICTION_CODE  \
# 0           45-64       M            WHITE HISPANIC                  0
# 1           18-24       M  ASIAN / PACIFIC ISLANDER                  0
# 2           25-44       F            BLACK HISPANIC                  2
# 3         UNKNOWN  (null)                    (null)                  0
# 4           18-24       M                     WHITE                  0
# ...           ...     ...                       ...                ...
# 1384329     45-64       M                   UNKNOWN                  0
# 1384330     25-44       M                   UNKNOWN                  0
# 1384331       NaN       D                   UNKNOWN                  0
# 1384332     45-64       M                   UNKNOWN                  0
# 1384333       <18       M                   UNKNOWN                  0
#
#               BORO  PRECINCT_OF_OCCUR  X_COORDINATE_CD  Y_COORDINATE_CD  \
# 0        MANHATTAN                 14         985927.0         213077.0
# 1            BRONX                 49        1020823.0         249562.0
# 2        MANHATTAN                 32         998922.0         235604.0
# 3         BROOKLYN                 94        1001547.0         203048.0
# 4        MANHATTAN                  6         984439.0         204595.0
# ...            ...                ...              ...              ...
# 1384329   BROOKLYN                 70         995708.0         176233.0
# 1384330      BRONX                 44        1008656.0         245335.0
# 1384331  MANHATTAN                  7         987559.0         201831.0
# 1384332   BROOKLYN                 67        1003469.0         171347.0
# 1384333      BRONX                 41        1015630.0         236919.0
#
#           Latitude  Longitude                                       Lon_Lat  \
# 0        40.751523 -73.993947  POINT (-73.99394730218468 40.75152348693427)
# 1        40.851589 -73.867801  POINT (-73.86780058180116 40.85158922344624)
# 2        40.813352 -73.946996                  POINT (-73.946996 40.813352)
# 3        40.723980 -73.937597  POINT (-73.93759674847603 40.72397961334044)
# 4        40.728254 -73.999318                  POINT (-73.999318 40.728254)
# ...            ...        ...                                           ...
# 1384329  40.650396 -73.958709  POINT (-73.95870942899995 40.65039633400005)
# 1384330  40.840038 -73.911797  POINT (-73.91179707599997 40.84003765600005)
# 1384331  40.720664 -73.988064  POINT (-73.98806399499993 40.72066379300003)
# 1384332  40.636972 -73.930754  POINT (-73.93075448599996 40.63697187500002)
# 1384333  40.816916 -73.886632  POINT (-73.88663211599999 40.81691612900005)
#
#          YEAR
# 0        2024
# 1        2024
# 2        2024
# 3        2024
# 4        2024
# ...       ...
# 1384329  2015
# 1384330  2015
# 1384331  2015
# 1384332  2015
# 1384333  2015
#
# [1384334 rows x 18 columns]

# %%
# 4. What were some of the most unusual summons?
nypd_summons = nypd_summons["OFFENSE_DESCRIPTION"].unique()
nypd_summons
# Out:
# <StringArray>
# [                                                   'DISORDERLY CONDUCT',
#                                                        'IMPROPER PLATES',
#                                                               'TRESPASS',
#                                          'FEDERAL MOTOR VEH. SAFETY REG',
#                                       'POSSESSION OF ALCOHOL BY A MINOR',
#                                                          'POSS. OF MACE',
#                                      'CONSUMPTION OF ALCOHOL IN VEHICLE',
#    'ENGAGES IN FIGHTING, OR VIOLENT, TUMULTUOUS OR THREATENING BEHAVIOR',
#      'OPERATION WHILE REGISTRATION OR PRIVILEGE IS SUSPENDED OR REVOKED',
#  'UNREASONABLE NOISE; FROM CAR MUFFLER/EXHAUST (HEARD FROM 150 FT AWAY)',
#  ...
#                                                         'NOISE (ANIMAL)',
#                                       'UNAUTHORIZED COLOR (TAXI YELLOW)',
#                                                           'INTERSECTION',
#                                                                'TRUANCY',
#                                                     'DRIVE THRU BARRIER',
#                                                 'NO STANDING (BUS LANE)',
#                                           'NO PARKING (STREET CLEANING)',
#                                                         'METER (BROKEN)',
#                                                      'BICYCLE NO LIGHTS',
#                                    'COMMERCIAL VEHICLE PARKED OVERNIGHT']
# Length: 781, dtype: str

# %%
# 5. What is the count of summons by gender?
nypd_summons["SEX"].value_counts()[["M", "F"]]
# Out:
# SEX
# M    1013591
# F     130370
# Name: count, dtype: int64

# %%
# 6. How many summons were issued by race?
nypd_summons["RACE"].value_counts()
# Out:
# RACE
# BLACK                             316676
# WHITE HISPANIC                    192409
# UNKNOWN                           185869
# WHITE                              87448
# BLACK HISPANIC                     70375
# (null)                             54376
# ASIAN / PACIFIC ISLANDER           49862
# AMERICAN INDIAN/ALASKAN NATIVE      5735
# OTHER                               2019
# Name: count, dtype: int64

# %% [markdown]
# # 2020 Census population
# ```python
# populations = {
#     "BROOKLYN": 2736074,
#     "QUEENS": 2405464,
#     "MANHATTAN": 1694251,
#     "BRONX": 1472654,
#     "STATEN ISLAND": 495747
# }
# ```

# %%
#7. Which borough had the fewest offenses per 100K people?


# 2020 Census population
populations = {
    "BROOKLYN": 2736074,
    "QUEENS": 2405464,
    "MANHATTAN": 1694251,
    "BRONX": 1472654,
    "STATEN ISLAND": 495747
}


boro_counts = nypd_summons["BORO"].value_counts()

boro_counts
# Out:
# BORO
# BROOKLYN         427679
# BRONX            312327
# MANHATTAN        275884
# QUEENS           246314
# NEW YORK          63056
# STATEN ISLAND     46824
# Name: count, dtype: int64

# %%
pop_series = pd.Series(populations)
pop_series
# Out:
# BROOKLYN         2736074
# QUEENS           2405464
# MANHATTAN        1694251
# BRONX            1472654
# STATEN ISLAND     495747
# dtype: int64

# %%
offenses_per_100k = (boro_counts / pop_series) * 100000

offenses_per_100k
# Out:
# BORO
# BRONX            21208.444074
# BROOKLYN         15631.119626
# MANHATTAN        16283.537681
# NEW YORK                  NaN
# QUEENS           10239.770789
# STATEN ISLAND     9445.140364
# dtype: float64

# %%
offenses_per_100k.idxmin()
# Out:
# 'STATEN ISLAND'
